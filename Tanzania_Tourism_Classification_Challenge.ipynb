# %%
import pandas as pd
from pandas_profiling import profile_report
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
from sklearn.metrics import log_loss, accuracy_score
from sklearn.model_selection import (RandomizedSearchCV, 
                                     GridSearchCV, KFold, 
                                     StratifiedShuffleSplit, 
                                     TimeSeriesSplit)
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier

# %%
# %matplotlib inline

# %%
train = pd.read_csv("Train.csv")
test = pd.read_csv("Test.csv")
# vard = pd.read_csv("VariableDefinitions.csv")

# %%
train.head(3)
# Out:
#            Tour_ID                   country age_group    travel_with  \
# 0  tour_id1hffseyw                     ITALY     45-64  With Children
# 1  tour_idnacd7zag            UNITED KINGDOM     25-44    With Spouse
# 2  tour_id62vz7e71  UNITED STATES OF AMERICA       65+    With Spouse
#
#    total_female  total_male                         purpose     main_activity  \
# 0           0.0         2.0  Visiting Friends and Relatives     Beach Tourism
# 1           1.0         1.0            Leisure and Holidays  Wildlife Tourism
# 2           1.0         1.0            Leisure and Holidays   Widlife Tourism
#
#                    info_source tour_arrangement  ... package_accomodation  \
# 0           Friends, relatives     Package Tour  ...                  Yes
# 1  Travel agent, tour operator     Package Tour  ...                  Yes
# 2  Travel agent, tour operator     Package Tour  ...                  Yes
#
#   package_food package_transport_tz package_sightseeing package_guided_tour  \
# 0          Yes                  Yes                  No                  No
# 1          Yes                  Yes                  No                  No
# 2          Yes                  Yes                 Yes                 Yes
#
#   package_insurance night_mainland  night_zanzibar  first_trip_tz  \
# 0                No              0               7            Yes
# 1                No              0               7            Yes
# 2                No              6               6            Yes
#
#   cost_category
# 0     High Cost
# 1     High Cost
# 2   Higher Cost
#
# [3 rows x 21 columns]

# %%
test.head(3)
# Out:
#            Tour_ID         country age_group    travel_with  total_female  \
# 0  tour_idynufedne           KOREA     25-44          Alone           0.0
# 1  tour_id9r3y5moe  UNITED KINGDOM     45-64  With Children           1.0
# 2  tour_idf6itml6g           ITALY     25-44    With Spouse           1.0
#
#    total_male               purpose       main_activity  \
# 0         1.0  Leisure and Holidays     Widlife Tourism
# 1         1.0  Leisure and Holidays  Conference Tourism
# 2         1.0  Leisure and Holidays       Beach Tourism
#
#                    info_source tour_arrangement package_transport_int  \
# 0                       Others      Independent                    No
# 1  Travel agent, tour operator     Package Tour                   Yes
# 2  Travel agent, tour operator     Package Tour                   Yes
#
#   package_accomodation package_food package_transport_tz package_sightseeing  \
# 0                   No           No                   No                  No
# 1                  Yes          Yes                  Yes                 Yes
# 2                  Yes           No                  Yes                  No
#
#   package_guided_tour package_insurance  night_mainland  night_zanzibar  \
# 0                  No                No               7               4
# 1                 Yes               Yes               7               0
# 2                  No                No               0               6
#
#   first_trip_tz
# 0           Yes
# 1           Yes
# 2           Yes

# %%
# vard["Definition"]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18506 entries, 0 to 18505
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Tour_ID                18506 non-null  object
#  1   country                18506 non-null  object
#  2   age_group              18506 non-null  object
#  3   travel_with            17431 non-null  object
#  4   total_female           18504 non-null  float64
#  5   total_male             18500 non-null  float64
#  6   purpose                18506 non-null  object
#  7   main_activity          18506 non-null  object
#  8   info_source            18506 non-null  object
#  9   tour_arrangement       18506 non-null  object
#  10  package_transport_int  18506 non-null  object
#  11  package_accomodation   18506 non-null  object
#  12  package_food           18506 non-null  object
#  13  package_transport_tz   18506 non-null  object
#  14  package_sightseeing    18506 non-null  object
#  15  package_guided_tour    18506 non-null  object
#  16  package_insurance      18506 non-null  object
#  17  night_mainland         18506 non-null  int64
#  18  night_zanzibar         18506 non-null  int64
#  19  first_trip_tz          18506 non-null  object
#  20  cost_category          18506 non-null  object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 3.0+ MB

# %%
train.describe()
# Out:
#        total_female    total_male  night_mainland  night_zanzibar
# count  18504.000000  18500.000000    18506.000000    18506.000000
# mean       0.936230      0.998757        9.141576        2.493516
# std        1.215582      1.173177       14.127449        5.275156
# min        0.000000      0.000000        0.000000        0.000000
# 25%        0.000000      1.000000        3.000000        0.000000
# 50%        1.000000      1.000000        6.000000        0.000000
# 75%        1.000000      1.000000       11.000000        4.000000
# max       49.000000     58.000000      365.000000      240.000000

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6169 entries, 0 to 6168
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Tour_ID                6169 non-null   object
#  1   country                6169 non-null   object
#  2   age_group              6169 non-null   object
#  3   travel_with            5808 non-null   object
#  4   total_female           6167 non-null   float64
#  5   total_male             6168 non-null   float64
#  6   purpose                6169 non-null   object
#  7   main_activity          6169 non-null   object
#  8   info_source            6169 non-null   object
#  9   tour_arrangement       6169 non-null   object
#  10  package_transport_int  6169 non-null   object
#  11  package_accomodation   6169 non-null   object
#  12  package_food           6169 non-null   object
#  13  package_transport_tz   6169 non-null   object
#  14  package_sightseeing    6169 non-null   object
#  15  package_guided_tour    6169 non-null   object
#  16  package_insurance      6169 non-null   object
#  17  night_mainland         6169 non-null   int64
#  18  night_zanzibar         6169 non-null   int64
#  19  first_trip_tz          6169 non-null   object
# dtypes: float64(2), int64(2), object(16)
# memory usage: 964.0+ KB

# %%
train["cost_category"].unique()
# Out:
# array(['High Cost', 'Higher Cost', 'Lower Cost', 'Normal Cost',
#        'Low Cost', 'Highest Cost'], dtype=object)

# %%
train["cost_category"].value_counts()
# Out:
# Normal Cost     5471
# Higher Cost     4865
# High Cost       3678
# Lower Cost      2567
# Low Cost        1566
# Highest Cost     359
# Name: cost_category, dtype: int64

# %%
# train.profile_report()

# %% [markdown]
# ## Handling missing values

# %%
# total nan values in columns
train.loc[:, train.isnull().any()].isnull().sum()
# Out:
# travel_with     1075
# total_female       2
# total_male         6
# dtype: int64

# %%
test.loc[:, test.isnull().any()].isnull().sum()
# Out:
# travel_with     361
# total_female      2
# total_male        1
# dtype: int64

# %%
print("travel_with : ", train["travel_with"].unique())
print("total_female : ", train["total_female"].unique())
print("total_male : ", train["total_male"].unique())
# Out:
# travel_with :  ['With Children' 'With Spouse' 'With Spouse and Children' 'Alone' nan
#  'With Other Friends/Relatives']
# total_female :  [ 0.  1.  3.  2.  4. 49.  5.  6.  7. 10. 13. 14.  8. 15. 20. 17. 11. 12.
#  24.  9. 22. nan 26. 19. 23.]
# total_male :  [ 2.  1.  0.  8.  4.  5.  3. 44.  7.  6. 14. 10. 12. 15. 24. 11.  9. 58.
#  nan 13. 40. 23. 20. 17. 25.]

# %%
# Filling nan values with most frequent category
def fill_nan(df):
    nan_cols = df.loc[:, df.isnull().any()].isnull().sum().index
    for col in nan_cols:
        df[col].fillna(df[col].mode()[0], inplace=True)
        # print(f"{col} : {train[col].isnull().sum()}")
    return df

# %%
train_1 = fill_nan(train)
test_1 = fill_nan(test)

print(train_1.loc[:, train_1.isnull().any()].isnull().sum())
print(test_1.loc[:, test_1.isnull().any()].isnull().sum())
# Out:
# Series([], dtype: float64)
# Series([], dtype: float64)

# %% [markdown]
# ## Feature Engineering

# %%
# Creating 2 new features "total_people" and "total_night_spent"
train_1["total_people"] = train_1["total_male"] + train_1["total_female"]
train_1["total_night_spent"] = train_1["night_mainland"] + train_1["night_zanzibar"]

test_1["total_people"] = test_1["total_male"] + test_1["total_female"]
test_1["total_night_spent"] = test_1["night_mainland"] + test_1["night_zanzibar"]

# %%
# Mapping "Yes" to 1 and "No" to 0
# and creating a new feature "total_package"

map_bool = {"Yes":1,
           "No":0}
cols = [col for col in train_1.columns if col.startswith("package")]
train_2 = train_1.loc[:,cols]
for col in cols:
    train_2[col] = train_2[col].map(map_bool)

train_1["total_package"] = (train_2["package_accomodation"] + train_2["package_food"] + train_2["package_guided_tour"] + 
                           train_2["package_insurance"] + train_2["package_sightseeing"] + 
                           train_2["package_transport_int"] + train_2["package_transport_tz"])

# %%
train_1.head(1)
# Out:
#            Tour_ID country age_group    travel_with  total_female  total_male  \
# 0  tour_id1hffseyw   ITALY     45-64  With Children           0.0         2.0
#
#                           purpose  main_activity         info_source  \
# 0  Visiting Friends and Relatives  Beach Tourism  Friends, relatives
#
#   tour_arrangement  ... package_sightseeing package_guided_tour  \
# 0     Package Tour  ...                  No                  No
#
#   package_insurance night_mainland night_zanzibar first_trip_tz cost_category  \
# 0                No              0              7           Yes     High Cost
#
#    total_people  total_night_spent total_package
# 0           2.0                  7             4
#
# [1 rows x 24 columns]

# %%
cols = [col for col in test_1.columns if col.startswith("package")]
test_2 = test_1.loc[:,cols]
for col in cols:
    test_2[col] = test_2[col].map(map_bool)

test_1["total_package"] = (test_2["package_accomodation"] + test_2["package_food"] + test_2["package_guided_tour"] + 
                           test_2["package_insurance"] + test_2["package_sightseeing"] + 
                           test_2["package_transport_int"] + test_2["package_transport_tz"])

test_1.head(2)
# Out:
#            Tour_ID         country age_group    travel_with  total_female  \
# 0  tour_idynufedne           KOREA     25-44          Alone           0.0
# 1  tour_id9r3y5moe  UNITED KINGDOM     45-64  With Children           1.0
#
#    total_male               purpose       main_activity  \
# 0         1.0  Leisure and Holidays     Widlife Tourism
# 1         1.0  Leisure and Holidays  Conference Tourism
#
#                    info_source tour_arrangement  ... package_transport_tz  \
# 0                       Others      Independent  ...                   No
# 1  Travel agent, tour operator     Package Tour  ...                  Yes
#
#   package_sightseeing package_guided_tour package_insurance night_mainland  \
# 0                  No                  No                No              7
# 1                 Yes                 Yes               Yes              7
#
#   night_zanzibar first_trip_tz  total_people  total_night_spent total_package
# 0              4           Yes           1.0                 11             0
# 1              0           Yes           2.0                  7             7
#
# [2 rows x 23 columns]

# %% [markdown]
# ## Encoding Categorical variables

# %%
# function to print name of boolean categorical columns and their unique values
def disp_bool_cat_cols(df):
    boolean_cols = []
    for col in df.columns:
        if df[col].nunique() <= 2:
            boolean_cols.append(col)
            print(f"{col} : {df[col].unique()}")
        
    
    
    
# function to return categorical columns with 2 unique categories
def ret_bool_cat_cols(df):
    boolean_cols = []
    for col in df.columns:
        if df[col].nunique() <=2:
            boolean_cols.append(col)
    
    return boolean_cols

# %%
disp_bool_cat_cols(train)
# Out:
# tour_arrangement : ['Package Tour' 'Independent']
# package_transport_int : ['Yes' 'No']
# package_accomodation : ['Yes' 'No']
# package_food : ['Yes' 'No']
# package_transport_tz : ['Yes' 'No']
# package_sightseeing : ['No' 'Yes']
# package_guided_tour : ['No' 'Yes']
# package_insurance : ['No' 'Yes']
# first_trip_tz : ['Yes' 'No']

# %%
# Function to encode categorical columns wiht 2 unique values
def encode_bool_cat_cols(df):
    boolean_cols = ret_bool_cat_cols(df)
    for col in boolean_cols:
        less_occured_cat = df[col].value_counts().nlargest().index[1] # category which occured less in the column
        less_occured_cat_col = col+"_"+less_occured_cat
        df = pd.get_dummies(data=df, columns=[col]).drop(less_occured_cat_col, axis="columns") # encoding most occuring category
    
    return df

# %%
# Encoding categorical variables with 2 unique categories in train set
train_1 = encode_bool_cat_cols(train)
train_1.head(2)
# Out:
#            Tour_ID         country age_group    travel_with  total_female  \
# 0  tour_id1hffseyw           ITALY     45-64  With Children           0.0
# 1  tour_idnacd7zag  UNITED KINGDOM     25-44    With Spouse           1.0
#
#    total_male                         purpose     main_activity  \
# 0         2.0  Visiting Friends and Relatives     Beach Tourism
# 1         1.0            Leisure and Holidays  Wildlife Tourism
#
#                    info_source  night_mainland  ...  total_package  \
# 0           Friends, relatives               0  ...              4
# 1  Travel agent, tour operator               0  ...              4
#
#   tour_arrangement_Package Tour  package_transport_int_No  \
# 0                             1                         0
# 1                             1                         0
#
#    package_accomodation_No  package_food_No  package_transport_tz_No  \
# 0                        0                0                        0
# 1                        0                0                        0
#
#    package_sightseeing_No  package_guided_tour_No  package_insurance_No  \
# 0                       1                       1                     1
# 1                       1                       1                     1
#
#    first_trip_tz_Yes
# 0                  1
# 1                  1
#
# [2 rows x 24 columns]

# %%
# disp_bool_cat_cols(test)

# %%
# Encoding categorical columns having 2 unique categories
test_1 = encode_bool_cat_cols(test)
test_1.drop("tour_arrangement_Independent", axis=1, inplace=True)
test_1["tour_arrangement_Package Tour"] = pd.get_dummies(data=test["tour_arrangement"], drop_first=True)

test_1.head(3)
# Out:
#            Tour_ID         country age_group    travel_with  total_female  \
# 0  tour_idynufedne           KOREA     25-44          Alone           0.0
# 1  tour_id9r3y5moe  UNITED KINGDOM     45-64  With Children           1.0
# 2  tour_idf6itml6g           ITALY     25-44    With Spouse           1.0
#
#    total_male               purpose       main_activity  \
# 0         1.0  Leisure and Holidays     Widlife Tourism
# 1         1.0  Leisure and Holidays  Conference Tourism
# 2         1.0  Leisure and Holidays       Beach Tourism
#
#                    info_source  night_mainland  ...  total_package  \
# 0                       Others               7  ...              0
# 1  Travel agent, tour operator               7  ...              7
# 2  Travel agent, tour operator               0  ...              3
#
#    package_transport_int_No  package_accomodation_No  package_food_No  \
# 0                         1                        1                1
# 1                         0                        0                0
# 2                         0                        0                1
#
#    package_transport_tz_No  package_sightseeing_No  package_guided_tour_No  \
# 0                        1                       1                       1
# 1                        0                       0                       0
# 2                        0                       1                       1
#
#    package_insurance_No  first_trip_tz_Yes  tour_arrangement_Package Tour
# 0                     1                  1                              0
# 1                     0                  1                              1
# 2                     1                  1                              1
#
# [3 rows x 23 columns]

# %%
# Checking for columns only present in train set
for col in train_1.columns:
    if col not in test_1.columns:
        print(col)
# Out:
# cost_category

# %%
# Slecting columns with more than 2 unique categories
train_1.select_dtypes(include='object').head()
# Out:
#            Tour_ID                   country age_group  \
# 0  tour_id1hffseyw                     ITALY     45-64
# 1  tour_idnacd7zag            UNITED KINGDOM     25-44
# 2  tour_id62vz7e71  UNITED STATES OF AMERICA       65+
# 3  tour_idrc76tzix                    RWANDA     25-44
# 4  tour_idn723m0n9  UNITED STATES OF AMERICA     45-64
#
#                 travel_with                         purpose     main_activity  \
# 0             With Children  Visiting Friends and Relatives     Beach Tourism
# 1               With Spouse            Leisure and Holidays  Wildlife Tourism
# 2               With Spouse            Leisure and Holidays   Widlife Tourism
# 3  With Spouse and Children            Leisure and Holidays     Beach Tourism
# 4                     Alone            Leisure and Holidays   Widlife Tourism
#
#                    info_source cost_category
# 0           Friends, relatives     High Cost
# 1  Travel agent, tour operator     High Cost
# 2  Travel agent, tour operator   Higher Cost
# 3               Radio, TV, Web    Lower Cost
# 4  Travel agent, tour operator   Higher Cost

# %%
# Encoding categorical columns having more than 1 unique categories
train_1 = pd.get_dummies(data=train_1, columns=[
                                     "age_group",
                                     "travel_with",
                                     "purpose",
                                     "main_activity",
                                     "info_source"])

train_1["country"] = LabelEncoder().fit_transform(train_1["country"])

# cols = ["country",
#         "tour_arrangement",
#          "age_group",
#           "travel_with",
#           "purpose",
#          "main_activity",
#         "info_source"]
# for col in cols:
#     train_1[col] = OrdinalEncoder().fit_transform(train_1[[col]])
#     test_1[col] = OrdinalEncoder().fit_transform(test_1[[col]])
train_1.head(3)
# Out:
#            Tour_ID  country  total_female  total_male  night_mainland  \
# 0  tour_id1hffseyw       54           0.0         2.0               0
# 1  tour_idnacd7zag      123           1.0         1.0               0
# 2  tour_id62vz7e71      124           1.0         1.0               6
#
#    night_zanzibar cost_category  total_people  total_night_spent  \
# 0               7     High Cost           2.0                  7
# 1               7     High Cost           2.0                  7
# 2               6   Higher Cost           2.0                 12
#
#    total_package  ...  main_activity_Widlife Tourism  \
# 0              4  ...                              0
# 1              4  ...                              0
# 2              6  ...                              1
#
#    main_activity_Wildlife Tourism  info_source_Friends, relatives  \
# 0                               0                               1
# 1                               1                               0
# 2                               0                               0
#
#    info_source_Inflight magazines  \
# 0                               0
# 1                               0
# 2                               0
#
#    info_source_Newspaper, magazines, brochures  info_source_Others  \
# 0                                            0                   0
# 1                                            0                   0
# 2                                            0                   0
#
#    info_source_Radio, TV, Web  info_source_Tanzania Mission Abroad  \
# 0                           0                                    0
# 1                           0                                    0
# 2                           0                                    0
#
#    info_source_Trade fair  info_source_Travel agent, tour operator
# 0                       0                                        0
# 1                       0                                        1
# 2                       0                                        1
#
# [3 rows x 55 columns]

# %%
# Encoding categorical columns having more than 1 unique categories
test_1 = pd.get_dummies(data=test_1, columns=[
                                     "age_group",
                                     "travel_with",
                                     "purpose",
                                     "main_activity",
                                     "info_source"])

test_1["country"] = OrdinalEncoder().fit_transform(test_1[["country"]])
test_1.head(3)
# Out:
#            Tour_ID  country  total_female  total_male  night_mainland  \
# 0  tour_idynufedne     57.0           0.0         1.0               7
# 1  tour_id9r3y5moe    112.0           1.0         1.0               7
# 2  tour_idf6itml6g     52.0           1.0         1.0               0
#
#    night_zanzibar  total_people  total_night_spent  total_package  \
# 0               4           1.0                 11              0
# 1               0           2.0                  7              7
# 2               6           2.0                  6              3
#
#    package_transport_int_No  ...  main_activity_Widlife Tourism  \
# 0                         1  ...                              1
# 1                         0  ...                              0
# 2                         0  ...                              0
#
#    main_activity_Wildlife Tourism  info_source_Friends, relatives  \
# 0                               0                               0
# 1                               0                               0
# 2                               0                               0
#
#    info_source_Inflight magazines  \
# 0                               0
# 1                               0
# 2                               0
#
#    info_source_Newspaper, magazines, brochures  info_source_Others  \
# 0                                            0                   1
# 1                                            0                   0
# 2                                            0                   0
#
#    info_source_Radio, TV, Web  info_source_Tanzania Mission Abroad  \
# 0                           0                                    0
# 1                           0                                    0
# 2                           0                                    0
#
#    info_source_Trade fair  info_source_Travel agent, tour operator
# 0                       0                                        0
# 1                       0                                        1
# 2                       0                                        1
#
# [3 rows x 54 columns]

# %%
tour_id = test_1["Tour_ID"]
test_1.drop("Tour_ID", axis=1, inplace=True)

# %%
test_1.head(2)
# Out:
#    country  total_female  total_male  night_mainland  night_zanzibar  \
# 0     57.0           0.0         1.0               7               4
# 1    112.0           1.0         1.0               7               0
#
#    total_people  total_night_spent  total_package  package_transport_int_No  \
# 0           1.0                 11              0                         1
# 1           2.0                  7              7                         0
#
#    package_accomodation_No  ...  main_activity_Widlife Tourism  \
# 0                        1  ...                              1
# 1                        0  ...                              0
#
#    main_activity_Wildlife Tourism  info_source_Friends, relatives  \
# 0                               0                               0
# 1                               0                               0
#
#    info_source_Inflight magazines  \
# 0                               0
# 1                               0
#
#    info_source_Newspaper, magazines, brochures  info_source_Others  \
# 0                                            0                   1
# 1                                            0                   0
#
#    info_source_Radio, TV, Web  info_source_Tanzania Mission Abroad  \
# 0                           0                                    0
# 1                           0                                    0
#
#    info_source_Trade fair  info_source_Travel agent, tour operator
# 0                       0                                        0
# 1                       0                                        1
#
# [2 rows x 53 columns]

# %% [markdown]
# ## Feature Selection

# %%
X = train_1.drop(["cost_category", "Tour_ID"], axis=1)
le = LabelEncoder()
y = le.fit_transform(train_1["cost_category"])

# %%
le.classes_
# Out:
# array(['High Cost', 'Higher Cost', 'Highest Cost', 'Low Cost',
#        'Lower Cost', 'Normal Cost'], dtype=object)

# %%
X.shape
# Out:
# (18506, 53)

# %%
y.shape
# Out:
# (18506,)

# %%
y
# Out:
# array([0, 0, 1, ..., 1, 1, 3])

# %%
# # Train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X.values, y, test_size=0.05, shuffle=True, random_state=42)

# %% [markdown]
# # Machine Learning Algorithms

# %%
import warnings
warnings.filterwarnings('ignore', '.*do not.*', )

# %% [markdown]
# ## RandomForrestClassifier

# %%
# Kfold_split
# KF = KFold(n_splits=5)
# for train_index, test_index in KF.split(X.values):
#     X_train, X_test = X.iloc[train_index], X.iloc[test_index]
#     y_train, y_test = y[train_index], y[test_index]
    
#     rf = RandomForestClassifier(n_estimators=400, max_depth=7)
#     rf.fit(X_train, y_train)
#     rf_preds_proba = rf.predict_proba(X_test)
#     lg_loss = log_loss(y_test, rf_preds_proba)
#     print(f"log_loss : {lg_loss}")

# %%
#StratifiedShuffleSplit
# ssp = StratifiedShuffleSplit(test_size=0.02, random_state=42)
# for train_index, test_index in ssp.split(X.values, y):
#     X_train, X_test = X.iloc[train_index], X.iloc[test_index]
#     y_train, y_test = y[train_index], y[test_index]
    
    # rf = RandomForestClassifier(n_estimators=400, max_depth=7)
    # rf.fit(X_train, y_train)
    # rf_preds_proba = rf.predict_proba(X_test)
    # lg_loss = log_loss(y_test, rf_preds_proba)
    # print(f"log_loss : {lg_loss}")

# %%
# Random Forrest 
# rf = RandomForestClassifier(n_estimators=400, max_depth=7)
# rf.fit(X_train, y_train)

# rf_preds = rf.predict(X_test)
# rf_preds_proba = rf.predict_proba(X_test)

# ll = log_loss(y_test, rf_preds_proba)
# ll

# %%
# rf_preds_proba_test = rf.predict_proba(test_1.values)
# rf_preds_test = rf.predict(test_1.values)

# %%
# sub_file = pd.DataFrame(data=rf_preds_proba_test, columns = le.classes_)
# sub_file.insert(0, column="Tour_ID", value=tour_id)
# # sub_file["preds"] = rf_preds_test
# sub_file

# %%
# kf = KFold()
# params = {"n_estimators":[200, 300, 400, 500],
#         "max_depth": [3, 4, 5, 6, 7, 8]}

# rsv = RandomizedSearchCV(estimator=rf, param_distributions=params, cv=kf)
# rsv.fit(X_train, y_train)
# print(rsv.best_params_)
# print(rsv.best_score_)

# %% [markdown]
# ## XGboost

# %%
ssp = StratifiedShuffleSplit(test_size=0.02, random_state=42)
for train_index, test_index in ssp.split(X.values, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    xgb = XGBClassifier(use_label_encoder=False,
                        n_estimators=63,
                       num_class=6,
                       learning_rate=0.13,
                       max_depth=7,
                       eval_metric='mlogloss',
                       random_state=42)
    xgb.fit(X_train.values, y_train)
    xgb_preds_proba = xgb.predict_proba(X_test.values)
    lg_loss = log_loss(y_test, xgb_preds_proba)
    print(f"log_loss : {lg_loss}")
# Out:
# log_loss : 1.1038707623012223
# log_loss : 1.0514968166233234
# log_loss : 1.1181471011327766
# log_loss : 1.0393887412335192
# log_loss : 1.036961639684065
# log_loss : 1.1172419112035126
# log_loss : 1.0853148686355658
# log_loss : 1.110337963134472
# log_loss : 1.1010671780567687
# log_loss : 1.052442390647418

# %%
xgb = XGBClassifier(use_label_encoder=False,
                    n_estimators=63,
                    num_class=6,
                  learning_rate=0.13,
                  max_depth=7,
                  eval_metric='mlogloss',
                   random_state=42)
xgb.fit(X_train.values, y_train)
xgb_preds_proba = xgb.predict_proba(X_test.values)
lg_loss = log_loss(y_test, xgb_preds_proba)
print(f"log_loss : {lg_loss}")
# Out:
# log_loss : 1.052442390647418

# %%
xgb_preds =  xgb.predict(X_test.values)
from sklearn.metrics import accuracy_score
accuracy_score(y_test, xgb_preds)
# Out:
# 0.5956873315363881

# %%
xgb_preds_proba_test = xgb.predict_proba(test_1.values)

# %%
sub_file = pd.DataFrame(data=xgb_preds_proba_test, columns = le.classes_)
sub_file.insert(0, column="Tour_ID", value=tour_id)
# sub_file["preds"] = rf_preds_test
sub_file.head()
# Out:
#            Tour_ID  High Cost  Higher Cost  Highest Cost  Low Cost  \
# 0  tour_idynufedne   0.304219     0.108099      0.003224  0.007461
# 1  tour_id9r3y5moe   0.332436     0.425187      0.022449  0.030327
# 2  tour_idf6itml6g   0.368384     0.333632      0.015181  0.020479
# 3  tour_id99u4znru   0.123708     0.117910      0.003483  0.041377
# 4  tour_idj4i9urbx   0.066696     0.034316      0.002199  0.006058
#
#    Lower Cost  Normal Cost
# 0    0.069228     0.507769
# 1    0.036878     0.152723
# 2    0.010543     0.251780
# 3    0.107029     0.606493
# 4    0.051098     0.839633

# %%
sub_file.to_csv("xgb_1.csv")

# %%
# params = {"n_estimators":[50, 53, 60, 65],
#          "max_depth":[6, 7, 8, 9],
#          "learning_rate":[0.1],
#          }
# rsv = RandomizedSearchCV(estimator=xgb, param_distributions=params, cv=ssp)
# rsv.fit(X_train.values, y_train)
# print(rsv.best_params_)
# print(rsv.best_score_)
# print(rsv.best_estimator_)

# %%
# xgb = XGBClassifier(use_label_encoder=False,
#                     n_estimators=60,
#                     num_class=6,
#                   learning_rate=0.13,
#                   max_depth=7,
#                   eval_metric='mlogloss',
#                    random_state=42)
# xgb.fit(X_train.values, y_train)
# xgb_preds_proba = xgb.predict_proba(X_test.values)
# lg_loss = log_loss(y_test, xgb_preds_proba)
# print(f"log_loss : {lg_loss}")

# %% [markdown]
# ## Catboost

# %%
err1=[]

fold=StratifiedShuffleSplit(n_splits=10, random_state=42)
for train_index, test_index in fold.split(X.values,y):
    X_train, X_test = X.iloc[train_index],X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    m2 = CatBoostClassifier(random_state=42)
    m2.fit(X_train.values,y_train,eval_set=[(X_train.values,y_train),(X_test.values, y_test)],early_stopping_rounds = 50,verbose=100,)
    preds = m2.predict_proba(X_test.values)
    print("err: ",(log_loss(y_test,preds)))
    err1.append((log_loss(y_test,preds)))
    p2 = m2.predict_proba(test_1)
print("The average score of Catboost is: ",np.mean(err1))
# Out:
# Learning rate set to 0.114224
# 0:	learn: 1.6592282	test: 1.6592282	test1: 1.6616318	best: 1.6616318 (0)	total: 16.4ms	remaining: 16.4s
# 100:	learn: 1.0260664	test: 1.0260664	test1: 1.1048393	best: 1.1048098 (99)	total: 1.26s	remaining: 11.3s
# 200:	learn: 0.9706267	test: 0.9706267	test1: 1.0959785	best: 1.0950444 (197)	total: 2.43s	remaining: 9.66s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 1.095044432
# bestIteration = 197
#
# Shrink model to first 198 iterations.
# err:  1.0950444324555075
# Learning rate set to 0.114224
# 0:	learn: 1.6600508	test: 1.6600508	test1: 1.6610585	best: 1.6610585 (0)	total: 12.1ms	remaining: 12.1s
# 100:	learn: 1.0278495	test: 1.0278495	test1: 1.0840907	best: 1.0840907 (100)	total: 1.2s	remaining: 10.7s
# 200:	learn: 0.9690353	test: 0.9690353	test1: 1.0753769	best: 1.0752577 (198)	total: 2.36s	remaining: 9.4s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 1.075216229
# bestIteration = 229
#
# Shrink model to first 230 iterations.
# err:  1.0752162287385991
# Learning rate set to 0.114224
# 0:	learn: 1.6599097	test: 1.6599097	test1: 1.6593525	best: 1.6593525 (0)	total: 11.2ms	remaining: 11.2s
# 100:	learn: 1.0303066	test: 1.0303066	test1: 1.0761782	best: 1.0761782 (100)	total: 1.18s	remaining: 10.5s
# 200:	learn: 0.9700977	test: 0.9700977	test1: 1.0596950	best: 1.0594558 (199)	total: 2.38s	remaining: 9.48s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 1.05823822
# bestIteration = 243
#
# Shrink model to first 244 iterations.
# err:  1.0582382197412348
# Learning rate set to 0.114224
# 0:	learn: 1.6596689	test: 1.6596689	test1: 1.6609089	best: 1.6609089 (0)	total: 12.2ms	remaining: 12.2s
# 100:	learn: 1.0303347	test: 1.0303347	test1: 1.0655893	best: 1.0655757 (99)	total: 1.24s	remaining: 11.1s
# 200:	learn: 0.9740451	test: 0.9740451	test1: 1.0501696	best: 1.0498814 (192)	total: 2.5s	remaining: 9.96s
# 300:	learn: 0.9327426	test: 0.9327426	test1: 1.0444524	best: 1.0444524 (300)	total: 3.66s	remaining: 8.51s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 1.043910787
# bestIteration = 312
#
# Shrink model to first 313 iterations.
# err:  1.0439107867819557
# Learning rate set to 0.114224
# 0:	learn: 1.6598966	test: 1.6598966	test1: 1.6616583	best: 1.6616583 (0)	total: 13.3ms	remaining: 13.2s
# 100:	learn: 1.0280372	test: 1.0280372	test1: 1.0919697	best: 1.0919697 (100)	total: 1.19s	remaining: 10.6s
# 200:	learn: 0.9723138	test: 0.9723138	test1: 1.0827268	best: 1.0819813 (190)	total: 2.42s	remaining: 9.6s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 1.081981286
# bestIteration = 190
#
# Shrink model to first 191 iterations.
# err:  1.0819812856827464
# Learning rate set to 0.114224
# 0:	learn: 1.6602121	test: 1.6602121	test1: 1.6624780	best: 1.6624780 (0)	total: 12.5ms	remaining: 12.4s
# 100:	learn: 1.0238572	test: 1.0238572	test1: 1.0977147	best: 1.0977147 (100)	total: 1.19s	remaining: 10.6s
# 200:	learn: 0.9671334	test: 0.9671334	test1: 1.0869098	best: 1.0867601 (197)	total: 2.38s	remaining: 9.46s
# 300:	learn: 0.9257599	test: 0.9257599	test1: 1.0837315	best: 1.0834169 (296)	total: 3.54s	remaining: 8.23s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 1.082910305
# bestIteration = 312
#
# Shrink model to first 313 iterations.
# err:  1.0829103045100916
# Learning rate set to 0.114224
# 0:	learn: 1.6598829	test: 1.6598829	test1: 1.6590349	best: 1.6590349 (0)	total: 12.8ms	remaining: 12.8s
# 100:	learn: 1.0287598	test: 1.0287598	test1: 1.0866806	best: 1.0866019 (99)	total: 1.27s	remaining: 11.3s
# 200:	learn: 0.9688883	test: 0.9688883	test1: 1.0757630	best: 1.0755210 (193)	total: 2.44s	remaining: 9.68s
# 300:	learn: 0.9267367	test: 0.9267367	test1: 1.0747810	best: 1.0747810 (300)	total: 3.66s	remaining: 8.5s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 1.074524143
# bestIteration = 313
#
# Shrink model to first 314 iterations.
# err:  1.0745241432528396
# Learning rate set to 0.114224
# 0:	learn: 1.6606463	test: 1.6606463	test1: 1.6586557	best: 1.6586557 (0)	total: 13.7ms	remaining: 13.7s
# 100:	learn: 1.0299536	test: 1.0299536	test1: 1.0662194	best: 1.0662194 (100)	total: 1.19s	remaining: 10.6s
# 200:	learn: 0.9717319	test: 0.9717319	test1: 1.0534563	best: 1.0531758 (192)	total: 2.42s	remaining: 9.62s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 1.053175763
# bestIteration = 192
#
# Shrink model to first 193 iterations.
# err:  1.0531757628227918
# Learning rate set to 0.114224
# 0:	learn: 1.6601988	test: 1.6601988	test1: 1.6603057	best: 1.6603057 (0)	total: 11.5ms	remaining: 11.5s
# 100:	learn: 1.0271393	test: 1.0271393	test1: 1.0721332	best: 1.0721332 (100)	total: 1.18s	remaining: 10.5s
# 200:	learn: 0.9684258	test: 0.9684258	test1: 1.0604737	best: 1.0602984 (196)	total: 2.41s	remaining: 9.59s
# 300:	learn: 0.9287964	test: 0.9287964	test1: 1.0593822	best: 1.0584448 (286)	total: 3.58s	remaining: 8.31s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 1.058444811
# bestIteration = 286
#
# Shrink model to first 287 iterations.
# err:  1.0584448113724503
# Learning rate set to 0.114224
# 0:	learn: 1.6603064	test: 1.6603064	test1: 1.6596053	best: 1.6596053 (0)	total: 12.4ms	remaining: 12.4s
# 100:	learn: 1.0259185	test: 1.0259185	test1: 1.0873143	best: 1.0872766 (99)	total: 1.19s	remaining: 10.6s
# 200:	learn: 0.9713444	test: 0.9713444	test1: 1.0799455	best: 1.0794661 (188)	total: 2.35s	remaining: 9.34s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 1.07946612
# bestIteration = 188
#
# Shrink model to first 189 iterations.
# err:  1.0794661199217856
# The average score of Catboost is:  1.0702912095280002

# %%
ssp = StratifiedShuffleSplit(test_size=0.02, random_state=42)
for train_index, test_index in ssp.split(X.values, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    cb = CatBoostClassifier(learning_rate=0.1,
                           iterations=1000,
                           use_best_model=True,
                           loss_function='MultiClass',
                           random_state=42,
                           logging_level='Silent',
                           )
    cb.fit(X_train.values, y_train, eval_set=(X_test.values, y_test))
    cb_preds_proba = cb.predict_proba(X_test.values)
    lg_loss = log_loss(y_test, cb_preds_proba)
    print(f"log_loss : {lg_loss}")
# Out:
# log_loss : 1.116222706084465
# log_loss : 1.0591738132755855
# log_loss : 1.1177894366930536
# log_loss : 1.0604207528499887
# log_loss : 1.034622174442958
# log_loss : 1.1328874144088472
# log_loss : 1.0727654987128947
# log_loss : 1.0843951673314705
# log_loss : 1.079289728089745
# log_loss : 1.061982451903247

# %%
cb = CatBoostClassifier(learning_rate=0.1,
                       iterations=1000,
                       use_best_model=True,
                       loss_function='MultiClass',
                       random_state=42,
                       logging_level='Silent',
                       )
cb.fit(X_train.values, y_train, eval_set=(X_test.values, y_test))
cb_preds_proba = cb.predict_proba(X_test.values)
lg_loss = log_loss(y_test, cb_preds_proba)
print(f"log_loss : {lg_loss}")
# Out:
# log_loss : 1.061982451903247

# %%
cb_test_proba = cb.predict_proba(test_1.values)

# %%
sub_file = pd.DataFrame(data=cb_test_proba, columns = le.classes_)
sub_file.insert(0, column="Tour_ID", value=tour_id)
# sub_file["preds"] = rf_preds_test
sub_file.head()
# Out:
#            Tour_ID  High Cost  Higher Cost  Highest Cost  Low Cost  \
# 0  tour_idynufedne   0.220529     0.069345      0.000682  0.052041
# 1  tour_id9r3y5moe   0.211672     0.451729      0.019988  0.030862
# 2  tour_idf6itml6g   0.408035     0.292482      0.002706  0.014179
# 3  tour_id99u4znru   0.101887     0.136653      0.000420  0.166464
# 4  tour_idj4i9urbx   0.112351     0.056605      0.000197  0.100815
#
#    Lower Cost  Normal Cost
# 0    0.052620     0.604782
# 1    0.021507     0.264243
# 2    0.003532     0.279067
# 3    0.161949     0.432628
# 4    0.145795     0.584238

# %%
sub_file.to_csv("cb_1.csv", index=None)
